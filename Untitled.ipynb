# %%
df = pd.read_csv('goodreads.csv')
df
# Out:
#                                                    Desc  \
# 0     In this age of an open Internet, it is easy to...
# 1     Personal finance author and lecturer Robert T....
# 2     Many of our favorite ingredients—such as berri...
# 3     Self-education is the key to upgrading your mi...
# 4     No-one is better than Diana Henry at turning t...
# ...                                                 ...
# 2032  In the tradition of Phil Knight's Shoe Dog com...
# 2033  Full of incredible characters, amazing athleti...
# 2034  The tenth anniversary edition of this landmark...
# 2035  Human rights activist Park, who fled North Kor...
# 2036  The Art of Startup Fundraising takes a fresh l...
#
#                         author        genre  \
# 0            King Arthur Flour  Non-Fiction
# 1               Michael Pollan  Non-Fiction
# 2              James W. Loewen     Business
# 3             Irma S. Rombauer  Non-Fiction
# 4     William N. Thorndike Jr.      Cooking
# ...

# %%
import os
os.listdir('.')
# Out:
# ['books_scraper.py',
#  'README.md',
#  '.ipynb_checkpoints',
#  'results',
#  'shelves_pages',
#  'authors_source_pages_mobile',
#  'shelves.txt',
#  '_data',
#  'shelves_pages_books_urls',
#  'stats',
#  'shelves_merger.py',
#  'requirements.txt',
#  'authors_urls',
#  '.git',
#  '.flake8',
#  '__pycache__',
#  'books_source_pages',
#  '.gitignore',
#  'goodreads.csv',
#  'Untitled.ipynb',
#  'authors_scraper.py',
#  'read_data.py']
